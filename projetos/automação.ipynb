# %%
import pyautogui
import time
import pyperclip

pyautogui.PAUSE = 0.1

pyautogui.alert("programa sendo executado não utilizar o computador")

pyautogui.hotkey('ctrl', 't') 
pyautogui.hotkey ('alt','space','x') #maximiza a tela
link = 'https://drive.google.com/drive/folders/1wRTFw0sUVBjRr4hW5U9LF7DjLixRyxym'
pyperclip.copy(link)
pyautogui.write(link)
pyautogui.press('enter')
time.sleep(2)
pyautogui.click(473,418)
time.sleep(4)
pyautogui.click(1716,185)
time.sleep (4)
pyautogui.click (1561,543)
time.sleep (10)
pyautogui.press('enter')
time.sleep (5)
pyautogui.click(814,500)
time.sleep (10)

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1425, y=1017)

# %%
import pandas as pd
tabela = pd.read_excel(r"C:\Users\CASA\Documents\JUPYTER\Vendas.xlsx")
display(tabela)
faturamento = tabela["Valor Final"].sum()
qtde_produtos = tabela["Quantidade"].sum()
print ("Faturamento = ",faturamento)
print ("Quantidade de produtos = ",qtde_produtos)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
import pyperclip
import pyautogui
import time
faturamento = 2917311
qtde_produtos = 15227
pyautogui.hotkey('ctrl', 't') 
pyautogui.hotkey ('alt','space','x') #maximiza a tela
link = "https://mail.google.com/"
pyautogui.write(link)
time.sleep (1)
pyautogui.press('enter')
time.sleep (8)

pyautogui.click(73,180)
time.sleep (5)
pyautogui.write ("jkarenldev+diretoria@gmail.com")
pyautogui.press('tab')
time.sleep (1)
pyautogui.press('tab')
assunto = 'Relatório de Vendas'
pyperclip.copy(assunto)
time.sleep(2)
pyautogui.hotkey("ctrl", 'v')

pyautogui.press ('tab')
texto_email = f"""
Prezados, Bom dia!

O faturamento de ontem foi: R$ {faturamento:,.2f}
A quantidade de produtos foi de: {qtde_produtos:,}

Sem mais para o momento 

Julia Karen Lacerda"""
pyperclip.copy (texto_email)
pyautogui.hotkey("ctrl", 'v')

time.sleep (3)
pyautogui.click (1425,1017)

time.sleep (3)
pyautogui.alert("Fim da Automação")
# Out:
# 'OK'
